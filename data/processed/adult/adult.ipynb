# %%
import pandas as pd

# %%
df = pd.read_csv("adult_mpa_bin_wout_agg.csv", sep=',', index_col=0)
print(df.columns[:10])
print(df.columns[-1])
print(len(df.columns))
# Out:
# Index(['age', 'sex', 'race', 'education_ 10th', 'education_ 11th',
#        'education_ 12th', 'education_ 1st-4th', 'education_ 5th-6th',
#        'education_ 7th-8th', 'education_ 9th'],
#       dtype='object')
# income
# 98

# %%
df = pd.read_csv("adult_mpa_cat_wout_agg.csv", sep=',', index_col=0)
print(df.columns[:10])
print(df.columns[-1])
print(len(df.columns))
# Out:
# Index(['age', 'sex', 'race_ White', 'race_ Amer-Indian-Eskimo',
#        'race_ Asian-Pac-Islander', 'race_ Black', 'race_ Other',
#        'education_ 10th', 'education_ 11th', 'education_ 12th'],
#       dtype='object')
# income
# 103

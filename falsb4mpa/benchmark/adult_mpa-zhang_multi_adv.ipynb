# %% [markdown]
# ## Import libs

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.python.data import Dataset
from tensorflow.keras.optimizers import Adam
import seaborn as sns


from falsb4mpa.modeling.zhang.learning.multi_adv import train_loop as zhang_train
from falsb4mpa.dataset.load_data import load_data
from falsb4mpa.evaluation.evaluation import compute_metrics, compute_tradeoff, fair_evaluation
from falsb4mpa.modeling.zhang.models.multi_adv import ZhangMultAdv

# %% [markdown]
# ## Preliminaries

# %%
batch_size = 64
epochs = 100
learning_rate = 0.001
opt = Adam(learning_rate=learning_rate)

# %%
cv_seeds = [13]
# cv_seeds = [13, 29, 42, 55, 73]

# %% [markdown]
# ## Load data

# %%
data_name = 'adult-mpa-bin-wout-agg'

# %%
x, y, a1, a2 = load_data(data_name)
raw_data = (x, y, a1, a2)

# %%
xdim = x.shape[1]
ydim = y.shape[1]
a1dim = a1.shape[1]
a2dim = a2.shape[1]
zdim = 8
print(xdim, ydim, a1dim, a2dim, zdim)
# Out:
# 97 1 1 1 8

# %% [markdown]
# ## Result file

# %%
header = "model_name", "cv_seed", "clas_acc", "a1_dp", "a1_deqodds", "a1_deqopp", "a1_TN_g0", "a1_FP_g0", "a1_FN_g0", "a1_TP_g0", "a1_TN_g1", "a1_FP_g1", "a1_FN_g1", "a1_TP_g1", "a0_dp", "a0_deqodds", "a0_deqopp", "a0_TN_g0", "a0_FP_g0", "a0_FN_g0", "a0_TP_g0", "a0_TN_g1", "a0_FP_g1", "a0_FN_g1", "a0_TP_g1"

results = []

# %% [markdown]
# ## Testing

# %%
fairdef = "EqOdds"

for cv_seed in cv_seeds:
    x_train, x_test, y_train, y_test, a1_train, a1_test, a2_train, a2_test = train_test_split(
        x, y, a1, a2, test_size=0.3, random_state=cv_seed)

    train_data = Dataset.from_tensor_slices((x_train, y_train, a1_train, a2_train))
    train_data = train_data.batch(batch_size, drop_remainder=True)

    test_data = Dataset.from_tensor_slices((x_test, y_test, a1_test, a2_test))
    test_data = test_data.batch(batch_size, drop_remainder=True)

    opt = Adam(learning_rate=learning_rate)

    model = ZhangMultAdv(xdim=xdim, ydim=ydim, a1dim=a1dim, a2dim=a2dim, batch_size=batch_size, fairdef=fairdef)
    
    ret = zhang_train(model, raw_data, train_data, epochs, opt)

    Y, A1, A2, Y_hat, A1_hat, A2_hat = fair_evaluation(model, test_data)
    clas_acc, a1_dp, a1_deqodds, a1_deqopp, a1_confusion_matrix, a1_metrics_g0, a1_metrics_g1 = compute_metrics(Y, A1, Y_hat, A1_hat, a1dim)
    clas_acc, a2_dp, a2_deqodds, a2_deqopp, a2_confusion_matrix, a2_metrics_g0, a2_metrics_g1 = compute_metrics(Y, A2, Y_hat, A2_hat, a2dim)


    # fair_metrics = (dp, deqodds, deqopp)
    # tradeoff = []
    # for fair_metric in fair_metrics:
    #     tradeoff.append(compute_tradeoff(clas_acc, fair_metric))

    # result = ['Zhang4EqOdds', cv_seed, clas_acc, dp, deqodds, deqopp, tradeoff[0], tradeoff[1], tradeoff[2]] + metrics_a0 + metrics_a1

    result = ['Zhang4EqOdds', cv_seed, clas_acc, a1_dp, a1_deqodds, a1_deqopp] + a1_metrics_g0 + a1_metrics_g1 + [a2_dp, a2_deqodds, a2_deqopp] + a2_metrics_g0 + a2_metrics_g1


    results.append(result)

    del(opt)
# Out:
# /Users/lffpl/Projects/falsb4mpa/.venv/lib/python3.11/site-packages/keras/src/optimizers/base_optimizer.py:731: UserWarning: Gradients do not exist for variables ['U:0', 'c:0'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
#
| Clf loss/acc 0.42/0.84 | Adv1 loss/acc 2.09/0.67 | Adv2 loss/acc 1.16/0.86
# > Epoch: 74 | Clf loss/acc 0.42/0.84 | Adv1 loss/acc 2.09/0.67 | Adv2 loss/acc 1.16/0.86
# > Epoch: 75 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.10/0.67 | Adv2 loss/acc 1.16/0.86
# > Epoch: 76 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.10/0.67 | Adv2 loss/acc 1.16/0.86
# > Epoch: 77 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.10/0.67 | Adv2 loss/acc 1.17/0.86
# > Epoch: 78 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.11/0.67 | Adv2 loss/acc 1.17/0.86
# > Epoch: 79 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.11/0.67 | Adv2 loss/acc 1.17/0.86
# > Epoch: 80 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.11/0.67 | Adv2 loss/acc 1.17/0.86
# > Epoch: 81 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.11/0.67 | Adv2 loss/acc 1.18/0.86
# > Epoch: 82 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.12/0.67 | Adv2 loss/acc 1.18/0.86
# > Epoch: 83 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.12/0.67 | Adv2 loss/acc 1.18/0.86
# > Epoch: 84 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.12/0.67 | Adv2 loss/acc 1.18/0.86
# > Epoch: 85 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.13/0.67 | Adv2 loss/acc 1.18/0.86
# > Epoch: 86 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.13/0.67 | Adv2 loss/acc 1.19/0.86
# > Epoch: 87 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.13/0.67 | Adv2 loss/acc 1.19/0.86
# > Epoch: 88 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.13/0.67 | Adv2 loss/acc 1.19/0.86
# > Epoch: 89 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.14/0.67 | Adv2 loss/acc 1.19/0.86
# > Epoch: 90 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.14/0.67 | Adv2 loss/acc 1.19/0.86
# > Epoch: 91 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.14/0.67 | Adv2 loss/acc 1.20/0.86
# > Epoch: 92 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.14/0.67 | Adv2 loss/acc 1.20/0.86
# > Epoch: 93 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.15/0.67 | Adv2 loss/acc 1.20/0.86
# > Epoch: 94 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.15/0.67 | Adv2 loss/acc 1.20/0.86
# > Epoch: 95 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.15/0.67 | Adv2 loss/acc 1.20/0.86
# > Epoch: 96 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.15/0.67 | Adv2 loss/acc 1.21/0.86
# > Epoch: 97 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.16/0.67 | Adv2 loss/acc 1.21/0.86
# > Epoch: 98 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.16/0.67 | Adv2 loss/acc 1.21/0.86
# > Epoch: 99 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.16/0.67 | Adv2 loss/acc 1.21/0.86
# > Epoch: 100 | Clf loss/acc 0.41/0.84 | Adv1 loss/acc 2.16/0.67 | Adv2 loss/acc 1.21/0.86
# > Evaluation
# > Class Acc = 0.8369371891021729
# > Adv Acc = 0.8369371891021729
# > DP | DEqOdds | DEqOpp
# > 0.7984519600868225 | 0.9003307223320007 | 0.9042062163352966
# > Confusion Matrix
# TN: 9197.0 | FP: 961.0
# FN: 1241.0 | TP: 2105.0
# > Confusion Matrix for A = 0
# TN: 5446.0 | FP: 843.0
# FN: 1010.0 | TP: 1825.0
# > Confusion Matrix for A = 1
# TN: 3751.0 | FP: 118.0
# FN: 231.0 | TP: 280.0
# > Evaluation
# > Class Acc = 0.8369371891021729
# > Adv Acc = 0.8369371891021729
# > DP | DEqOdds | DEqOpp
# > 0.8510503768920898 | 0.8828262090682983 | 0.8471621870994568
# > Confusion Matrix
# TN: 9197.0 | FP: 961.0
# FN: 1241.0 | TP: 2105.0
# > Confusion Matrix for A = 0
# TN: 7626.0 | FP: 919.0
# FN: 1087.0 | TP: 1957.0
# > Confusion Matrix for A = 1
# TN: 1571.0 | FP: 42.0
# FN: 154.0 | TP: 148.0

# %%
sns.heatmap(a1_confusion_matrix, annot=True, fmt='g')
# Out:
# <Axes: >

# %%
sns.heatmap(a2_confusion_matrix, annot=True, fmt='g')
# Out:
# <Axes: >

# %% [markdown]
# ## Saving into DF then CSV

# %%
# result_df = pd.DataFrame(results, columns=header)
# result_df

# %%
# result_df.to_csv(f'{data_name}-result/unfair_lr-{epochs}.csv')

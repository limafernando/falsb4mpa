# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from falsb4mpa.dataset.utils import bucket

# %%
column_names = [
    'Survived',
    'Pclass', # ticket class (1, 2, 3)
    'Name',
    'Sex',
    'Age', # Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
    'SibSp', # # of siblings / spouses aboard the Titanic
    'Parch', # # of parents / children aboard the Titanic
    'Ticket', # Ticket number
    'Fare', # Passenger fare
    'Cabin', # Cabin number
    'Embarked' # Port of Embarkation
]

# %%
used_columns = [
    'Survived',
    'Pclass',
    'Sex',
    'Age',
    'SibSp',
    'Parch',
    'Fare',
    'Embarked'
]
target = 'Survived'
sensitive = 'Sex'

# %% [markdown]
# # Reading data

# %%
train_data = pd.read_csv("../../data/raw/titanic/titanic_train.csv", index_col='PassengerId')
test_data = pd.read_csv("../../data/raw/titanic/titanic_train.csv", index_col='PassengerId')

# %%
data = pd.concat([train_data, test_data])
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(len(data.index))
# Out:
# 1782

# %% [markdown]
# ### Remove unused columns

# %%
data = pd.DataFrame(data, columns=used_columns)

# %% [markdown]
# # Removing missing values

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         354
# SibSp         0
# Parch         0
# Fare          0
# Embarked      4
# dtype: int64

# %%
data.dropna(subset=['Survived'], inplace=True) 
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         354
# SibSp         0
# Parch         0
# Fare          0
# Embarked      4
# dtype: int64

# %%
print(len(data.index))
# Out:
# 1782

# %%
data.dropna(subset=['Embarked'], inplace=True) 
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         354
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
print(len(data.index))
# Out:
# 1778

# %%
data['Age'].fillna(-1, inplace=True) # indicate we dont have this data, but dont drop this data points
data.isna().sum()
# Out:
# /var/folders/nx/ktkztyln3xn8f8j2qrfpjrlh0000gn/T/ipykernel_7871/4270556205.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(-1, inplace=True) # indicate we dont have this data, but dont drop this data points
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
print(len(data.index))
# Out:
# 1778

# %% [markdown]
# # Normalizing continuous data

# %%
continous_attr = ['Fare']

# %% [markdown]
# # Age

# %%
data['Age'].describe()
# Out:
# count    1778.000000
# mean       23.541249
# std        17.829469
# min        -1.000000
# 25%         6.000000
# 50%        24.000000
# 75%        35.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
data['Age'].apply(np.floor).describe()
# Out:
# count    1778.000000
# mean       23.525309
# std        17.830493
# min        -1.000000
# 25%         6.000000
# 50%        24.000000
# 75%        35.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
data['Age'] = data['Age'].apply(np.floor)

# %%
data['Age'] = data['Age'].astype(int)

# %%
data[data['Age'] == 0]
# Out:
#              Survived  Pclass     Sex  Age  SibSp  Parch      Fare Embarked
# PassengerId
# 79                  1       2    male    0      0      2   29.0000        S
# 306                 1       1    male    0      1      2  151.5500        S
# 470                 1       3  female    0      2      1   19.2583        C
# 645                 1       3  female    0      2      1   19.2583        C
# 756                 1       2    male    0      1      1   14.5000        S
# 804                 1       3    male    0      0      1    8.5167        C
# 832                 1       2    male    0      1      1   18.7500        S
# 79                  1       2    male    0      0      2   29.0000        S
# 306                 1       1    male    0      1      2  151.5500        S
# 470                 1       3  female    0      2      1   19.2583        C
# 645                 1       3  female    0      2      1   19.2583        C
# 756                 1       2    male    0      1      1   14.5000        S
# 804                 1       3    male    0      0      1    8.5167        C
# 832                 1       2    male    0      1      1   18.7500        S

# %% [markdown]
# #### Bucketing age

# %%
data['Age'].head()
# Out:
# PassengerId
# 1    22
# 2    38
# 3    26
# 4    35
# 5    35
# Name: Age, dtype: int64

# %%
buckets = [-1, 2, 12, 18, 25 ,35, 45, 55, 65, 75, 80]

labels = ['Age_' + str(bucket) for bucket in buckets]
dict_labels = {i:labels[i] for i in range(len(labels))}
dict_labels
# Out:
# {0: 'Age_-1',
#  1: 'Age_2',
#  2: 'Age_12',
#  3: 'Age_18',
#  4: 'Age_25',
#  5: 'Age_35',
#  6: 'Age_45',
#  7: 'Age_55',
#  8: 'Age_65',
#  9: 'Age_75',
#  10: 'Age_80'}

# %%
bucket_train = data['Age'].apply(bucket, buckets=buckets).to_frame()

# %%
bucket_train = pd.get_dummies(bucket_train['Age'])
bucket_train.head()
# Out:
#                 0      1      2      3      4      5      6      7      8   \
# PassengerId
# 1            False  False  False  False   True  False  False  False  False
# 2            False  False  False  False  False  False   True  False  False
# 3            False  False  False  False  False   True  False  False  False
# 4            False  False  False  False  False   True  False  False  False
# 5            False  False  False  False  False   True  False  False  False
#
#                 9      10
# PassengerId
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# 5            False  False

# %%
bucket_train = bucket_train.rename(columns=dict_labels)
bucket_train.head()
# Out:
#              Age_-1  Age_2  Age_12  Age_18  Age_25  Age_35  Age_45  Age_55  \
# PassengerId
# 1             False  False   False   False    True   False   False   False
# 2             False  False   False   False   False   False    True   False
# 3             False  False   False   False   False    True   False   False
# 4             False  False   False   False   False    True   False   False
# 5             False  False   False   False   False    True   False   False
#
#              Age_65  Age_75  Age_80
# PassengerId
# 1             False   False   False
# 2             False   False   False
# 3             False   False   False
# 4             False   False   False
# 5             False   False   False

# %%
data = pd.concat([data, bucket_train], axis=1)
data.drop(['Age'], axis=1, inplace=True)
data.head()
# Out:
#              Survived  Pclass     Sex  SibSp  Parch     Fare Embarked  Age_-1  \
# PassengerId
# 1                   0       3    male      1      0   7.2500        S   False
# 2                   1       1  female      1      0  71.2833        C   False
# 3                   1       3  female      0      0   7.9250        S   False
# 4                   1       1  female      1      0  53.1000        S   False
# 5                   0       3    male      0      0   8.0500        S   False
#
#              Age_2  Age_12  Age_18  Age_25  Age_35  Age_45  Age_55  Age_65  \
# PassengerId
# 1            False   False   False    True   False   False   False   False
# 2            False   False   False   False   False    True   False   False
# 3            False   False   False   False    True   False   False   False
# 4            False   False   False   False    True   False   False   False
# 5            False   False   False   False    True   False   False   False
#
#              Age_75  Age_80
# PassengerId
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False

# %% [markdown]
# # Binarizing sex and survived

# %%
data['Survived'] = data['Survived'].astype(int)

# %%
data['Sex'] = pd.get_dummies(data['Sex'])['female']

# %%
data.head()
# Out:
#              Survived  Pclass    Sex  SibSp  Parch     Fare Embarked  Age_-1  \
# PassengerId
# 1                   0       3  False      1      0   7.2500        S   False
# 2                   1       1   True      1      0  71.2833        C   False
# 3                   1       3   True      0      0   7.9250        S   False
# 4                   1       1   True      1      0  53.1000        S   False
# 5                   0       3  False      0      0   8.0500        S   False
#
#              Age_2  Age_12  Age_18  Age_25  Age_35  Age_45  Age_55  Age_65  \
# PassengerId
# 1            False   False   False    True   False   False   False   False
# 2            False   False   False   False   False    True   False   False
# 3            False   False   False   False    True   False   False   False
# 4            False   False   False   False    True   False   False   False
# 5            False   False   False   False    True   False   False   False
#
#              Age_75  Age_80
# PassengerId
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False

# %% [markdown]
# # One hot encoding categorical data

# %%
categorical_attr = ['Embarked']

# %%
for attr in categorical_attr:
    column_idx = data.columns.get_loc(attr)
    data = pd.concat([data, pd.get_dummies(data[attr], prefix=attr)], axis=1)

# %%
data.head()
# Out:
#              Survived  Pclass    Sex  SibSp  Parch     Fare Embarked  Age_-1  \
# PassengerId
# 1                   0       3  False      1      0   7.2500        S   False
# 2                   1       1   True      1      0  71.2833        C   False
# 3                   1       3   True      0      0   7.9250        S   False
# 4                   1       1   True      1      0  53.1000        S   False
# 5                   0       3  False      0      0   8.0500        S   False
#
#              Age_2  Age_12  ...  Age_25  Age_35  Age_45  Age_55  Age_65  \
# PassengerId                 ...
# 1            False   False  ...    True   False   False   False   False
# 2            False   False  ...   False   False    True   False   False
# 3            False   False  ...   False    True   False   False   False
# 4            False   False  ...   False    True   False   False   False
# 5            False   False  ...   False    True   False   False   False
#
#              Age_75  Age_80  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 1             False   False       False       False        True
# 2             False   False        True       False       False
# 3             False   False       False       False        True
# 4             False   False       False       False        True
# 5             False   False       False       False        True
#
# [5 rows x 21 columns]

# %%
data.drop(categorical_attr, axis=1, inplace=True)

# %%
data.head()
# Out:
#              Survived  Pclass    Sex  SibSp  Parch     Fare  Age_-1  Age_2  \
# PassengerId
# 1                   0       3  False      1      0   7.2500   False  False
# 2                   1       1   True      1      0  71.2833   False  False
# 3                   1       3   True      0      0   7.9250   False  False
# 4                   1       1   True      1      0  53.1000   False  False
# 5                   0       3  False      0      0   8.0500   False  False
#
#              Age_12  Age_18  Age_25  Age_35  Age_45  Age_55  Age_65  Age_75  \
# PassengerId
# 1             False   False    True   False   False   False   False   False
# 2             False   False   False   False    True   False   False   False
# 3             False   False   False    True   False   False   False   False
# 4             False   False   False    True   False   False   False   False
# 5             False   False   False    True   False   False   False   False
#
#              Age_80  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 1             False       False       False        True
# 2             False        True       False       False
# 3             False       False       False        True
# 4             False       False       False        True
# 5             False       False       False        True

# %% [markdown]
# # Reordering the columns

# %%
columns_order = [
    'Pclass',
    'Fare',
    'Embarked_C',
    'Embarked_Q',
    'Embarked_S',
    'Age_-1',
    'Age_2',
    'Age_12',
    'Age_18',
    'Age_25',
    'Age_35',
    'Age_45',
    'Age_55',
    'Age_65',
    'Age_75',
    'Age_80',
    'SibSp',
    'Parch',
    'Sex',
    'Survived'
]

# %%
data.head()
# Out:
#              Survived  Pclass    Sex  SibSp  Parch     Fare  Age_-1  Age_2  \
# PassengerId
# 1                   0       3  False      1      0   7.2500   False  False
# 2                   1       1   True      1      0  71.2833   False  False
# 3                   1       3   True      0      0   7.9250   False  False
# 4                   1       1   True      1      0  53.1000   False  False
# 5                   0       3  False      0      0   8.0500   False  False
#
#              Age_12  Age_18  Age_25  Age_35  Age_45  Age_55  Age_65  Age_75  \
# PassengerId
# 1             False   False    True   False   False   False   False   False
# 2             False   False   False   False    True   False   False   False
# 3             False   False   False    True   False   False   False   False
# 4             False   False   False    True   False   False   False   False
# 5             False   False   False    True   False   False   False   False
#
#              Age_80  Embarked_C  Embarked_Q  Embarked_S
# PassengerId
# 1             False       False       False        True
# 2             False        True       False       False
# 3             False       False       False        True
# 4             False       False       False        True
# 5             False       False       False        True

# %%
data = data[columns_order]
data.head()
# Out:
#              Pclass     Fare  Embarked_C  Embarked_Q  Embarked_S  Age_-1  \
# PassengerId
# 1                 3   7.2500       False       False        True   False
# 2                 1  71.2833        True       False       False   False
# 3                 3   7.9250       False       False        True   False
# 4                 1  53.1000       False       False        True   False
# 5                 3   8.0500       False       False        True   False
#
#              Age_2  Age_12  Age_18  Age_25  Age_35  Age_45  Age_55  Age_65  \
# PassengerId
# 1            False   False   False    True   False   False   False   False
# 2            False   False   False   False   False    True   False   False
# 3            False   False   False   False    True   False   False   False
# 4            False   False   False   False    True   False   False   False
# 5            False   False   False   False    True   False   False   False
#
#              Age_75  Age_80  SibSp  Parch    Sex  Survived
# PassengerId
# 1             False   False      1      0  False         0
# 2             False   False      1      0   True         1
# 3             False   False      0      0   True         1
# 4             False   False      1      0   True         1
# 5             False   False      0      0  False         0

# %% [markdown]
# # Saving data

# %%
print(len(data.index))
# Out:
# 1778

# %%
data.to_csv('../../data/processed/titanic/titanic.csv')
